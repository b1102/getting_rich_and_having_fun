# %%
import sys
sys.path.append('../../src/')

import numpy as np
import tensorflow as tf
from tensorflow import keras
import seaborn as sns
import pandas as pd
import os
from matplotlib import pyplot
import matplotlib.pyplot as plt
from utils.utils import train_data, plot_results


# %matplotlib inline
os.environ["CUDA_VISIBLE_DEVICES"] = "-1"

# %%
name = "Reference"
activation = 'relu'
batch_size = 128
neurons_number = 64
epochs = 20
optimize = 'Adam'

# %%
# build the model
model = tf.keras.models.Sequential()
model.add(keras.layers.Dense(neurons_number, input_shape=(1,), name='input', activation=activation))
model.add(keras.layers.Dense(neurons_number, activation=activation))
# model.add(keras.layers.Dropout(0.2))
model.add(keras.layers.Dense(neurons_number, activation=activation))
# model.add(keras.layers.Dropout(0.2))
model.add(keras.layers.Dense(neurons_number, activation=activation))
# model.add(keras.layers.Dropout(0.2))
model.add(keras.layers.Dense(1, name='output'))
# summary of the model
model.summary()
model.compile(optimizer=optimize, loss='mean_squared_error', metrics=['mse', 'mean_absolute_error'])
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (Dense)                (None, 64)                128
# _________________________________________________________________
# dense (Dense)                (None, 64)                4160
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                4160
# _________________________________________________________________
# output (Dense)               (None, 1)                 65
# =================================================================
# Total params: 12,673
# Trainable params: 12,673
# Non-trainable params: 0
# _________________________________________________________________

# %%
X_train, Y_train = train_data(start=0, end=0.8, number=10000)
model.fit(X_train, Y_train, batch_size=batch_size, epochs=epochs, verbose=1, validation_split=0.2)
# Out:
# Epoch 1/20
# 63/63 [==============================] - 0s 4ms/step - loss: 0.0506 - mse: 0.0506 - mean_absolute_error: 0.1580 - val_loss: 1.2570e-04 - val_mse: 1.2570e-04 - val_mean_absolute_error: 0.0112
# Epoch 2/20
# 63/63 [==============================] - 0s 823us/step - loss: 6.2725e-05 - mse: 6.2725e-05 - mean_absolute_error: 0.0054 - val_loss: 1.2667e-05 - val_mse: 1.2667e-05 - val_mean_absolute_error: 0.0035
# Epoch 3/20
# 63/63 [==============================] - 0s 882us/step - loss: 1.0684e-05 - mse: 1.0684e-05 - mean_absolute_error: 0.0019 - val_loss: 3.9628e-06 - val_mse: 3.9628e-06 - val_mean_absolute_error: 0.0019
# Epoch 4/20
# 63/63 [==============================] - 0s 866us/step - loss: 3.8517e-06 - mse: 3.8517e-06 - mean_absolute_error: 0.0011 - val_loss: 2.0747e-06 - val_mse: 2.0747e-06 - val_mean_absolute_error: 0.0014
# Epoch 5/20
# 63/63 [==============================] - 0s 924us/step - loss: 1.5024e-06 - mse: 1.5024e-06 - mean_absolute_error: 5.4380e-04 - val_loss: 6.8931e-07 - val_mse: 6.8931e-07 - val_mean_absolute_error: 7.8271e-04
# Epoch 6/20
# 63/63 [==============================] - 0s 916us/step - loss: 9.5622e-07 - mse: 9.5622e-07 - mean_absolute_error: 4.2307e-04 - val_loss: 7.1492e-07 - val_mse: 7.1492e-07 - val_mean_absolute_error: 8.0368e-04
# Epoch 7/20
# 63/63 [==============================] - 0s 902us/step - loss: 4.7627e-07 - mse: 4.7627e-07 - mean_absolute_error: 3.2795e-04 - val_loss: 7.3225e-07 - val_mse: 7.3225e-07 - val_mean_absolute_error: 8.0881e-04
# Epoch 8/20
# 63/63 [==============================] - 0s 844us/step - loss: 2.5548e-07 - mse: 2.5548e-07 - mean_absolute_error: 2.0834e-04 - val_loss: 5.8736e-07 - val_mse: 5.8736e-07 - val_mean_absolute_error: 7.1148e-04
# Epoch 9/20
# 63/63 [==============================] - 0s 887us/step - loss: 1.6299e-07 - mse: 1.6299e-07 - mean_absolute_error: 1.5890e-04 - val_loss: 4.5965e-07 - val_mse: 4.5965e-07 - val_mean_absolute_error: 6.1125e-04
# Epoch 10/20
# 63/63 [==============================] - 0s 859us/step - loss: 1.0228e-07 - mse: 1.0228e-07 - mean_absolute_error: 1.3088e-04 - val_loss: 3.8849e-07 - val_mse: 3.8849e-07 - val_mean_absolute_error: 5.4697e-04
# Epoch 11/20
# 63/63 [==============================] - 0s 863us/step - loss: 7.0283e-08 - mse: 7.0283e-08 - mean_absolute_error: 1.0942e-04 - val_loss: 2.8785e-07 - val_mse: 2.8785e-07 - val_mean_absolute_error: 4.4669e-04
# Epoch 12/20
# 63/63 [==============================] - 0s 887us/step - loss: 5.0987e-08 - mse: 5.0987e-08 - mean_absolute_error: 9.6407e-05 - val_loss: 3.7054e-07 - val_mse: 3.7054e-07 - val_mean_absolute_error: 5.2495e-04
# Epoch 13/20
# 63/63 [==============================] - 0s 879us/step - loss: 4.5181e-08 - mse: 4.5181e-08 - mean_absolute_error: 9.0720e-05 - val_loss: 3.6686e-07 - val_mse: 3.6686e-07 - val_mean_absolute_error: 5.2205e-04
# Epoch 14/20
# 63/63 [==============================] - 0s 850us/step - loss: 3.1804e-08 - mse: 3.1804e-08 - mean_absolute_error: 8.8401e-05 - val_loss: 3.5703e-07 - val_mse: 3.5703e-07 - val_mean_absolute_error: 5.1005e-04
# Epoch 15/20
# 63/63 [==============================] - 0s 929us/step - loss: 3.0051e-08 - mse: 3.0051e-08 - mean_absolute_error: 7.7292e-05 - val_loss: 3.1059e-07 - val_mse: 3.1059e-07 - val_mean_absolute_error: 4.6097e-04
# Epoch 16/20
# 63/63 [==============================] - 0s 832us/step - loss: 2.3179e-08 - mse: 2.3179e-08 - mean_absolute_error: 7.5157e-05 - val_loss: 3.1084e-07 - val_mse: 3.1084e-07 - val_mean_absolute_error: 4.6053e-04
# Epoch 17/20
# 63/63 [==============================] - 0s 891us/step - loss: 2.0606e-08 - mse: 2.0606e-08 - mean_absolute_error: 6.7828e-05 - val_loss: 3.1616e-07 - val_mse: 3.1616e-07 - val_mean_absolute_error: 4.6279e-04
# Epoch 18/20
# 63/63 [==============================] - 0s 796us/step - loss: 1.7342e-08 - mse: 1.7342e-08 - mean_absolute_error: 6.8446e-05 - val_loss: 3.1023e-07 - val_mse: 3.1023e-07 - val_mean_absolute_error: 4.5659e-04
# Epoch 19/20
# 63/63 [==============================] - 0s 778us/step - loss: 1.7050e-08 - mse: 1.7050e-08 - mean_absolute_error: 6.6295e-05 - val_loss: 3.7314e-07 - val_mse: 3.7314e-07 - val_mean_absolute_error: 5.1639e-04
# Epoch 20/20
# 63/63 [==============================] - 0s 843us/step - loss: 1.5354e-08 - mse: 1.5354e-08 - mean_absolute_error: 6.4470e-05 - val_loss: 3.7312e-07 - val_mse: 3.7312e-07 - val_mean_absolute_error: 5.1431e-04

# %%
X_test, Y_test = train_data(start=0, end=1.0, number=333)
loss, mse, mean_absolute_error = model.evaluate(X_test, Y_test)
# Out:
# 11/11 [==============================] - 0s 291us/step - loss: 2.9861e-06 - mse: 2.9861e-06 - mean_absolute_error: 8.4332e-04

# %%
# %%
grid = np.linspace(0, 1.0, 150)
predicted = model.predict(grid).reshape((150,))

plot_results(grid, predicted, name, mean_absolute_error, 0.8)
